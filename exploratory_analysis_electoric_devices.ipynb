# %%
import pandas as pd
df2=pd.read_csv("supermarket_sales - Sheet1.csv")
df2.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df2.shape
df2['Payment'].unique()
# Out:
# array(['Ewallet', 'Cash', 'Credit card'], dtype=object)

# %%
individual_gross_income=df2.groupby('Product line').mean()['gross income']
# Out:
# C:\Users\hpopm\AppData\Local\Temp\ipykernel_4828\3422186064.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   individual_gross_income=df2.groupby('Product line').mean()['gross income']

# %%
respective_quantities=df2.groupby('Product line').sum()['Quantity']
# Out:
# C:\Users\hpopm\AppData\Local\Temp\ipykernel_4828\4166526996.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   respective_quantities=df2.groupby('Product line').sum()['Quantity']

# %%
respective_quantities.plot.bar()
# Out:
# <AxesSubplot: xlabel='Product line'>

# %%
individual_ratings_mean=df2.groupby('Product line').mean()['Rating']
# Out:
# C:\Users\hpopm\AppData\Local\Temp\ipykernel_4828\1223330571.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   individual_ratings_mean=df2.groupby('Product line').mean()['Rating']

# %%
individual_ratings_mean.plot.bar()
# Out:
# <AxesSubplot: xlabel='Product line'>

# %%
individual_gross_income.plot.bar()
# Out:
# <AxesSubplot: xlabel='Product line'>

# %%
df3=df2.where(df2['Product line']=='Electronic accessories')

# %%
df2['Product line'].unique()
# Out:
# array(['Health and beauty', 'Electronic accessories',
#        'Home and lifestyle', 'Sports and travel', 'Food and beverages',
#        'Fashion accessories'], dtype=object)

# %%
df3.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0          NaN    NaN        NaN           NaN     NaN
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2          NaN    NaN        NaN           NaN     NaN
# 3          NaN    NaN        NaN           NaN     NaN
# 4          NaN    NaN        NaN           NaN     NaN
#
#              Product line  Unit price  Quantity  Tax 5%  Total      Date  \
# 0                     NaN         NaN       NaN     NaN    NaN       NaN
# 1  Electronic accessories       15.28       5.0    3.82  80.22  3/8/2019
# 2                     NaN         NaN       NaN     NaN    NaN       NaN
# 3                     NaN         NaN       NaN     NaN    NaN       NaN
# 4                     NaN         NaN       NaN     NaN    NaN       NaN
#
#     Time Payment  cogs  gross margin percentage  gross income  Rating
# 0    NaN     NaN   NaN                      NaN           NaN     NaN
# ...

# %%
df_elec_acc=df3.dropna()

# %%
df3.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0          NaN    NaN        NaN           NaN     NaN
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2          NaN    NaN        NaN           NaN     NaN
# 3          NaN    NaN        NaN           NaN     NaN
# 4          NaN    NaN        NaN           NaN     NaN
#
#              Product line  Unit price  Quantity  Tax 5%  Total      Date  \
# 0                     NaN         NaN       NaN     NaN    NaN       NaN
# 1  Electronic accessories       15.28       5.0    3.82  80.22  3/8/2019
# 2                     NaN         NaN       NaN     NaN    NaN       NaN
# 3                     NaN         NaN       NaN     NaN    NaN       NaN
# 4                     NaN         NaN       NaN     NaN    NaN       NaN
#
#     Time Payment  cogs  gross margin percentage  gross income  Rating
# 0    NaN     NaN   NaN                      NaN           NaN     NaN
# ...

# %%
df_elec_acc.head()
# Out:
#      Invoice ID Branch       City Customer type  Gender  \
# 1   226-31-3081      C  Naypyitaw        Normal  Female
# 5   699-14-3026      C  Naypyitaw        Normal    Male
# 6   355-53-5943      A     Yangon        Member  Female
# 11  529-56-3974      B   Mandalay        Member    Male
# 12  365-64-0515      A     Yangon        Normal  Female
#
#               Product line  Unit price  Quantity   Tax 5%     Total  \
# 1   Electronic accessories       15.28       5.0   3.8200   80.2200
# 5   Electronic accessories       85.39       7.0  29.8865  627.6165
# 6   Electronic accessories       68.84       6.0  20.6520  433.6920
# 11  Electronic accessories       25.51       4.0   5.1020  107.1420
# 12  Electronic accessories       46.95       5.0  11.7375  246.4875
#
#          Date   Time  Payment    cogs  gross margin percentage  gross income  \
# 1    3/8/2019  10:29     Cash   76.40                 4.761905        3.8200
# ...

# %%
df_elec_acc.shape
# Out:
# (170, 17)

# %%
amount2=df_elec_acc['Unit price']*df_elec_acc['Quantity']
df_elec_acc['amount2']=amount2
df_elec_acc.plot.scatter(x='cogs', y='gross income', s=1)
# Out:
# C:\Users\hpopm\AppData\Local\Temp\ipykernel_4828\954286949.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_elec_acc['amount2']=amount2
# <AxesSubplot: xlabel='cogs', ylabel='gross income'>

# %%
import numpy as np

# %%
x=np.array(df_elec_acc['amount2'])

# %%
y=np.array(df_elec_acc['gross income'])

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x,y)
plt.xlim([1,100])
plt.ylim([1,5])
# Out:
# (1.0, 5.0)

# %%
df_elec_acc.sort_values('Date')
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 496  556-97-7101      C  Naypyitaw        Normal  Female
# 450  891-01-7034      B   Mandalay        Normal  Female
# 829  416-17-9926      A     Yangon        Member  Female
# 317  603-07-0961      C  Naypyitaw        Member    Male
# 925  226-34-0034      B   Mandalay        Normal  Female
# ..           ...    ...        ...           ...     ...
# 95   594-34-4444      A     Yangon        Normal    Male
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 45   132-32-9879      B   Mandalay        Member  Female
# 73   841-35-6630      C  Naypyitaw        Normal  Female
# 11   529-56-3974      B   Mandalay        Member    Male
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 496  Electronic accessories       63.22       2.0   6.3220  132.7620
# 450  Electronic accessories       74.71       6.0  22.4130  470.6730
# 829  Electronic accessories       74.22      10.0  37.1100  779.3100
# ...

# %%
df_elec_acc['Date']=pd.to_datetime(df_elec_acc['Date'] + ' ' + df_elec_acc['Time'])
# Out:
# C:\Users\hpopm\AppData\Local\Temp\ipykernel_4828\2419372486.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_elec_acc['Date']=pd.to_datetime(df_elec_acc['Date'] + ' ' + df_elec_acc['Time'])

# %%
df_elec_acc.dtypes
# Out:
# Invoice ID                         object
# Branch                             object
# City                               object
# Customer type                      object
# Gender                             object
# Product line                       object
# Unit price                        float64
# Quantity                          float64
# Tax 5%                            float64
# Total                             float64
# Date                       datetime64[ns]
# Time                               object
# Payment                            object
# cogs                              float64
# gross margin percentage           float64
# gross income                      float64
# Rating                            float64
# amount2                           float64
# dtype: object

# %%
df_elec_acc.head()
# Out:
#      Invoice ID Branch       City Customer type  Gender  \
# 1   226-31-3081      C  Naypyitaw        Normal  Female
# 5   699-14-3026      C  Naypyitaw        Normal    Male
# 6   355-53-5943      A     Yangon        Member  Female
# 11  529-56-3974      B   Mandalay        Member    Male
# 12  365-64-0515      A     Yangon        Normal  Female
#
#               Product line  Unit price  Quantity   Tax 5%     Total  \
# 1   Electronic accessories       15.28       5.0   3.8200   80.2200
# 5   Electronic accessories       85.39       7.0  29.8865  627.6165
# 6   Electronic accessories       68.84       6.0  20.6520  433.6920
# 11  Electronic accessories       25.51       4.0   5.1020  107.1420
# 12  Electronic accessories       46.95       5.0  11.7375  246.4875
#
#                   Date   Time  Payment    cogs  gross margin percentage  \
# 1  2019-03-08 10:29:00  10:29     Cash   76.40                 4.761905
# ...

# %%
df_elec_acc['Year'] = df_elec_acc['Date'].dt.year
# Out:
# C:\Users\hpopm\AppData\Local\Temp\ipykernel_4828\2871594846.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_elec_acc['Year'] = df_elec_acc['Date'].dt.year

# %%
df_elec_acc.head()
# Out:
#      Invoice ID Branch       City Customer type  Gender  \
# 1   226-31-3081      C  Naypyitaw        Normal  Female
# 5   699-14-3026      C  Naypyitaw        Normal    Male
# 6   355-53-5943      A     Yangon        Member  Female
# 11  529-56-3974      B   Mandalay        Member    Male
# 12  365-64-0515      A     Yangon        Normal  Female
#
#               Product line  Unit price  Quantity   Tax 5%     Total  \
# 1   Electronic accessories       15.28       5.0   3.8200   80.2200
# 5   Electronic accessories       85.39       7.0  29.8865  627.6165
# 6   Electronic accessories       68.84       6.0  20.6520  433.6920
# 11  Electronic accessories       25.51       4.0   5.1020  107.1420
# 12  Electronic accessories       46.95       5.0  11.7375  246.4875
#
#                   Date   Time  Payment    cogs  gross margin percentage  \
# 1  2019-03-08 10:29:00  10:29     Cash   76.40                 4.761905
# ...

# %%
df_elec_acc['Month'] = df_elec_acc['Date'].dt.month
    
df_elec_acc['Hour'] = df_elec_acc['Date'].dt.hour 
    
df_elec_acc['Minute'] = df_elec_acc['Date'].dt.minute
# Out:
# C:\Users\hpopm\AppData\Local\Temp\ipykernel_4828\1302350074.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_elec_acc['Month'] = df_elec_acc['Date'].dt.month
# C:\Users\hpopm\AppData\Local\Temp\ipykernel_4828\1302350074.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_elec_acc['Hour'] = df_elec_acc['Date'].dt.hour
# C:\Users\hpopm\AppData\Local\Temp\ipykernel_4828\1302350074.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df_elec_acc.head()
# Out:
#      Invoice ID Branch       City Customer type  Gender  \
# 1   226-31-3081      C  Naypyitaw        Normal  Female
# 5   699-14-3026      C  Naypyitaw        Normal    Male
# 6   355-53-5943      A     Yangon        Member  Female
# 11  529-56-3974      B   Mandalay        Member    Male
# 12  365-64-0515      A     Yangon        Normal  Female
#
#               Product line  Unit price  Quantity   Tax 5%     Total  ...  \
# 1   Electronic accessories       15.28       5.0   3.8200   80.2200  ...
# 5   Electronic accessories       85.39       7.0  29.8865  627.6165  ...
# 6   Electronic accessories       68.84       6.0  20.6520  433.6920  ...
# 11  Electronic accessories       25.51       4.0   5.1020  107.1420  ...
# 12  Electronic accessories       46.95       5.0  11.7375  246.4875  ...
#
#     Payment    cogs gross margin percentage  gross income  Rating  amount2  \
# 1      Cash   76.40                4.761905        3.8200     9.6    76.40
# ...

# %%
df_elec_acc['Year'].unique()
# Out:
# array([2019], dtype=int64)

# %%
monthly_revenue = df_elec_acc.groupby('Month').sum()['gross income']
# Out:
# C:\Users\hpopm\AppData\Local\Temp\ipykernel_4828\545180428.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   monthly_revenue = df_elec_acc.groupby('Month').sum()['gross income']

# %%
print(monthly_revenue)
# Out:
# Month
# 1    896.7280
# 2    826.8050
# 3    863.9685
# Name: gross income, dtype: float64
